# %% [markdown]
# # Deep Reinforcement Learning

# %% [markdown]
#  Reinforcement Learning (RL) is an approach wherein an agent learns to make sequential decisions by interacting with an environment. The objective is for the agent to maximize the cumulative reward it receives over time.
#  The agent goes through this process by repeatedly evaluating the consequences of its actions, trying to select actions that lead to better outcomes.
#
# To do this, we will use Gym, an platform for developing and comparing reinforcement learning algorithms. Gym provides an interface for interacting with different environments, it accepts actions from agents and plays them out in an environment, providing rewards.

# %% [markdown]
# ## Environment
#
# We will be using `CartPole` environment from gym's library for this assignment.  In this environment, a pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces in the left and right direction on the cart.
#
# You can use the code below to run an instance of a random agent in this environment and see the results.

# %%
from IPython.display import HTML
from base64 import b64encode

def show_video(path):
    mp4 = open(path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width=400 controls>
          <source src="%s" type="video/mp4">
    </video>
    """ % data_url)

# %%
# !pip install gym[atari,accept-rom-license] -qq
# !pip install imageio -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 14.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done

# %%
import cv2
import gym
import imageio
import numpy as np
from gym import spaces

# %% [markdown]
# We use `gym.make()` to make an instance of a certain environemtn. We can then use `.step()` method which accepts an action as input and performs it. Before that we reset the environment to its initial state by using `.reset()` method.

# %%
# Create an instance of the CartPole environment
env_name = 'CartPole-v1'
env = gym.make(env_name)

# Reset the environment to its initial state
env.reset()

# Initialize an empty list to store frames
frames = []

# Run the environment for a specified number of steps
for _ in range(500):
    action = env.action_space.sample()  # Take a random action
    obs, reward, done, _ = env.step(action)  # Perform the action and observe the result

    # Render this frame and add to the list of frames
    frames.append(env.render(mode='rgb_array'))

    if done:
        env.reset()

# Close the environment
env.close()

# Save the rendered frames as a video
imageio.mimsave('./cartpole.mp4', frames, fps=25)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %%
show_video('./cartpole.mp4')
# Out:
#     <video width=400 controls>
#           <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# As you can see, the cart fails to keep the balance of the pole. In the next section we will train an agent to learn how to perform this task.

# %% [markdown]
# ## Algorithm
# We will be using A2C algorithm.
#
# Advantage Actor-Critic (A2C) is a reinforcement learning algorithm.
# It consists of an actor (which predicts the best action based on the current state) and a critic (which estimates the state's value function to measure expected future rewards).
#
# We will implement this together step by step.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions.categorical import Categorical
import numpy as np
import gym
from collections import deque
from tqdm import tqdm
import imageio
from IPython.display import HTML
from base64 import b64encode

# %% [markdown]
# ## Neural Network
#
# Here we design a simple feed forward model to embed the observation from the environment to a hidden layer. We then use two fully connected layers on top of the hidden layer, to predict the next action and estimate the value of current state. This acts as both actor, and critic.
#
# You need to implement the convolutional neural network.

# %%
class ActorCritic(nn.Module):
    def __init__(self, input_size, hidden_size, num_outputs):
        super(ActorCritic, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc_action = nn.Linear(hidden_size, num_outputs)
        self.fc_value = nn.Linear(hidden_size, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        action_probs = F.softmax(self.fc_action(x), dim=-1)
        value = self.fc_value(x)
        return action_probs, value

# %% [markdown]
# ## A2C

# %% [markdown]
# The A2C algorithm aims to jointly train both the actor and the critic to improve the policy. It does this by updating the parameters
# of the actor to increase the likelihood of good actions and updating the parameters
# of the critic to better estimate the value function.
#
# In each iteration A2C plays the until it ends. During this time it records log probabality of actions, rewards, and predicted values in each step. These values will be used to update the model at the end of this trajectory.
#
# The actor is updated using the objective below:
#
# $$ L_{\text{actor}} = -\log \pi(a|s;\theta) \times A(s, a) $$
# Where advantage is calculated as:
# $$A(s, a) = Q(s, a) - V(s) $$
#
# Namely the function $Q(s,a)$ is the estimated value of taking action
# $a$
#  in state
# $s$.
# $V(s)$ is the predicted value of our critic.
#
# This loss function aims to improve the probability of playing actions that result in higher rewards.
#
# As for the critic the loss function is defined as a simple mean square loss between actual value of an state and the predicted one:
#
# $$ L_{\text{critic}} = \frac{1}{2} ( R - V(s))^2 $$

# %%
class A2CAgent:
    def __init__(self, env, num_episodes=2000, max_steps=500, gamma=0.99, lr=5e-4, hidden_size=256):
        self.env = env
        self.num_episodes = num_episodes
        self.max_steps = max_steps
        self.gamma = gamma
        self.lr = lr
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        input_size = env.observation_space.shape[0]
        num_outputs = env.action_space.n

        self.policy_net = ActorCritic(input_size, hidden_size, num_outputs).to(self.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.critic_loss = nn.MSELoss()

    def choose_action(self, state):
      if not isinstance(state, torch.Tensor):
          state = torch.FloatTensor(state).to(self.device)
      action_probs, _ = self.policy_net(state)
      action_dist = Categorical(action_probs)
      action = action_dist.sample()
      return action.item(), action_dist.log_prob(action)


    def compute_returns(self, rewards):
        R = 0
        returns = []
        for r in reversed(rewards):
            R = r + self.gamma * R
            returns.insert(0, R)
        return returns

    def train(self):
        episode_rewards = []
        with tqdm(range(self.num_episodes)) as pbar:
            for episode in pbar:
                state = self.env.reset()
                episode_reward = 0
                log_probs = []
                values = []
                rewards = []

                for step in range(self.max_steps):
                    state = torch.FloatTensor(state).to(self.device)
                    action, log_prob = self.choose_action(state)
                    value = self.policy_net(state)[1]

                    next_state, reward, done, _ = self.env.step(action)
                    log_probs.append(log_prob)
                    values.append(value)
                    rewards.append(reward)
                    episode_reward += reward

                    if done:
                        break

                    state = next_state

                episode_rewards.append(episode_reward)
                returns = self.compute_returns(rewards)
                returns = torch.FloatTensor(returns).to(self.device)
                log_probs = torch.stack(log_probs)
                values = torch.stack(values).squeeze()

                advantage = returns - values
                actor_loss = - (log_probs * advantage.detach()).mean()
                critic_loss = self.critic_loss(values, returns)
                loss = actor_loss + critic_loss

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                pbar.set_description(f"Episode {episode}, Reward: {episode_reward:.2f}")

        self.env.close()
        return episode_rewards

# %% [markdown]
# Define the model and set hyperparameters.

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

num_episodes = 3000
max_steps = 500
lr = 8e-4
hidden_size = 256

a2c_model = A2CAgent(env, num_episodes, max_steps, lr=lr, hidden_size=hidden_size)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# Train the model.

# %%
rewards = a2c_model.train()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 2999, Reward: 500.00: 100%|██████████| 3000/3000 [27:00<00:00,  1.85it/s]

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Use the `choose_action` method of the trained agent to evaluate its performance.

# %%
def show_video(path):
    mp4 = open(path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width=400 controls>
          <source src="%s" type="video/mp4">
    </video>
    """ % data_url)

env = gym.make(env_name, render_mode='rgb_array')
model = a2c_model

num_episodes = 10
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

frames = []
episode_rewards = []

for i in range(num_episodes):
    reset_output = env.reset()
    if isinstance(reset_output, tuple):
        state = reset_output[0]
    else:
        state = reset_output
    episode_reward = 0

    for step in range(max_steps):
        if not isinstance(state, torch.Tensor):
            state = torch.FloatTensor(state).to(device)
        action, _ = model.choose_action(state)

        step_output = env.step(action)
        if isinstance(step_output, tuple) and len(step_output) == 4:
            next_state, reward, done, _ = step_output
        else:
            next_state, reward, done, _, _ = step_output

        episode_reward += reward

        if i == 0:
            frame = env.render()
            frame = np.array(frame)  # Convert frame to numpy array if it's not already

            # Ensure the frame has 3 channels and correct shape
            if len(frame.shape) == 4 and frame.shape[0] == 1:  # If there's an extra dimension
                frame = frame[0]  # Remove the extra dimension

            if len(frame.shape) == 2:  # If the frame is grayscale
                frame = np.stack([frame]*3, axis=-1)
            elif frame.shape[-1] == 1:  # If the frame has a single channel
                frame = np.repeat(frame, 3, axis=-1)
            elif frame.shape[-1] > 3:  # If the frame has more than 3 channels
                frame = frame[..., :3]  # Discard extra channels

            # Log frame shape and type
            print(f"Frame shape: {frame.shape}, dtype: {frame.dtype}")

            # Log and add frame if valid
            if frame.shape == (400, 600, 3):
                frames.append(frame)
            else:
                print(f"Skipping frame with unexpected shape: {frame.shape}")

        if done:
            break

        state = next_state

    episode_rewards.append(episode_reward)
    print(f"Episode Reward: {episode_reward}")

env.close()

episode_rewards = np.array(episode_rewards)
print(f"Average Reward over {num_episodes} episodes: {np.mean(episode_rewards)}")

# Check if all frames have the correct shape
for idx, frame in enumerate(frames):
    print(f"Final check - Frame {idx}: shape {frame.shape}, dtype: {frame.dtype}")
    if frame.shape != (400, 600, 3):
        print(f"Frame {idx} has unexpected shape: {frame.shape}")

imageio.mimsave('./test.mp4', frames, fps=25)
show_video('./test.mp4')
# Out:
# Frame shape: (2, 400, 600, 3), dtype: uint8
# Skipping frame with unexpected shape: (2, 400, 600, 3)
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Frame shape: (400, 600, 3), dtype: uint8
# Episode Reward: 500.0
# Episode Reward: 455.0
# Episode Reward: 466.0
# Episode Reward: 500.0
# Episode Reward: 458.0
# Episode Reward: 295.0
# Episode Reward: 461.0
# Episode Reward: 331.0
# Episode Reward: 303.0
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode Reward: 458.0
# Average Reward over 10 episodes: 422.7
# Final check - Frame 0: shape (400, 600, 3), dtype: uint8
# Final check - Frame 1: shape (400, 600, 3), dtype: uint8
# Final check - Frame 2: shape (400, 600, 3), dtype: uint8
# Final check - Frame 3: shape (400, 600, 3), dtype: uint8
# Final check - Frame 4: shape (400, 600, 3), dtype: uint8
# Final check - Frame 5: shape (400, 600, 3), dtype: uint8
# Final check - Frame 6: shape (400, 600, 3), dtype: uint8
# Final check - Frame 7: shape (400, 600, 3), dtype: uint8
# Final check - Frame 8: shape (400, 600, 3), dtype: uint8
# Final check - Frame 9: shape (400, 600, 3), dtype: uint8
# Final check - Frame 10: shape (400, 600, 3), dtype: uint8
# Final check - Frame 11: shape (400, 600, 3), dtype: uint8
# Final check - Frame 12: shape (400, 600, 3), dtype: uint8
# Final check - Frame 13: shape (400, 600, 3), dtype: uint8
# Final check - Frame 14: shape (400, 600, 3), dtype: uint8
# Final check - Frame 15: shape (400, 600, 3), dtype: uint8
# Final check - Frame 16: shape (400, 600, 3), dtype: uint8
# Final check - Frame 17: shape (400, 600, 3), dtype: uint8
# Final check - Frame 18: shape (400, 600, 3), dtype: uint8
# Final check - Frame 19: shape (400, 600, 3), dtype: uint8
# Final check - Frame 20: shape (400, 600, 3), dtype: uint8
# Final check - Frame 21: shape (400, 600, 3), dtype: uint8
# Final check - Frame 22: shape (400, 600, 3), dtype: uint8
# Final check - Frame 23: shape (400, 600, 3), dtype: uint8
# Final check - Frame 24: shape (400, 600, 3), dtype: uint8
# Final check - Frame 25: shape (400, 600, 3), dtype: uint8
# Final check - Frame 26: shape (400, 600, 3), dtype: uint8
# Final check - Frame 27: shape (400, 600, 3), dtype: uint8
# Final check - Frame 28: shape (400, 600, 3), dtype: uint8
# Final check - Frame 29: shape (400, 600, 3), dtype: uint8
# Final check - Frame 30: shape (400, 600, 3), dtype: uint8
# Final check - Frame 31: shape (400, 600, 3), dtype: uint8
# Final check - Frame 32: shape (400, 600, 3), dtype: uint8
# Final check - Frame 33: shape (400, 600, 3), dtype: uint8
# Final check - Frame 34: shape (400, 600, 3), dtype: uint8
# Final check - Frame 35: shape (400, 600, 3), dtype: uint8
# Final check - Frame 36: shape (400, 600, 3), dtype: uint8
# Final check - Frame 37: shape (400, 600, 3), dtype: uint8
# Final check - Frame 38: shape (400, 600, 3), dtype: uint8
# Final check - Frame 39: shape (400, 600, 3), dtype: uint8
# Final check - Frame 40: shape (400, 600, 3), dtype: uint8
# Final check - Frame 41: shape (400, 600, 3), dtype: uint8
# Final check - Frame 42: shape (400, 600, 3), dtype: uint8
# Final check - Frame 43: shape (400, 600, 3), dtype: uint8
# Final check - Frame 44: shape (400, 600, 3), dtype: uint8
# Final check - Frame 45: shape (400, 600, 3), dtype: uint8
# Final check - Frame 46: shape (400, 600, 3), dtype: uint8
# Final check - Frame 47: shape (400, 600, 3), dtype: uint8
# Final check - Frame 48: shape (400, 600, 3), dtype: uint8
# Final check - Frame 49: shape (400, 600, 3), dtype: uint8
# Final check - Frame 50: shape (400, 600, 3), dtype: uint8
# Final check - Frame 51: shape (400, 600, 3), dtype: uint8
# Final check - Frame 52: shape (400, 600, 3), dtype: uint8
# Final check - Frame 53: shape (400, 600, 3), dtype: uint8
# Final check - Frame 54: shape (400, 600, 3), dtype: uint8
# Final check - Frame 55: shape (400, 600, 3), dtype: uint8
# Final check - Frame 56: shape (400, 600, 3), dtype: uint8
# Final check - Frame 57: shape (400, 600, 3), dtype: uint8
# Final check - Frame 58: shape (400, 600, 3), dtype: uint8
# Final check - Frame 59: shape (400, 600, 3), dtype: uint8
# Final check - Frame 60: shape (400, 600, 3), dtype: uint8
# Final check - Frame 61: shape (400, 600, 3), dtype: uint8
# Final check - Frame 62: shape (400, 600, 3), dtype: uint8
# Final check - Frame 63: shape (400, 600, 3), dtype: uint8
# Final check - Frame 64: shape (400, 600, 3), dtype: uint8
# Final check - Frame 65: shape (400, 600, 3), dtype: uint8
# Final check - Frame 66: shape (400, 600, 3), dtype: uint8
# Final check - Frame 67: shape (400, 600, 3), dtype: uint8
# Final check - Frame 68: shape (400, 600, 3), dtype: uint8
# Final check - Frame 69: shape (400, 600, 3), dtype: uint8
# Final check - Frame 70: shape (400, 600, 3), dtype: uint8
# Final check - Frame 71: shape (400, 600, 3), dtype: uint8
# Final check - Frame 72: shape (400, 600, 3), dtype: uint8
# Final check - Frame 73: shape (400, 600, 3), dtype: uint8
# Final check - Frame 74: shape (400, 600, 3), dtype: uint8
# Final check - Frame 75: shape (400, 600, 3), dtype: uint8
# Final check - Frame 76: shape (400, 600, 3), dtype: uint8
# Final check - Frame 77: shape (400, 600, 3), dtype: uint8
# Final check - Frame 78: shape (400, 600, 3), dtype: uint8
# Final check - Frame 79: shape (400, 600, 3), dtype: uint8
# Final check - Frame 80: shape (400, 600, 3), dtype: uint8
# Final check - Frame 81: shape (400, 600, 3), dtype: uint8
# Final check - Frame 82: shape (400, 600, 3), dtype: uint8
# Final check - Frame 83: shape (400, 600, 3), dtype: uint8
# Final check - Frame 84: shape (400, 600, 3), dtype: uint8
# Final check - Frame 85: shape (400, 600, 3), dtype: uint8
# Final check - Frame 86: shape (400, 600, 3), dtype: uint8
# Final check - Frame 87: shape (400, 600, 3), dtype: uint8
# Final check - Frame 88: shape (400, 600, 3), dtype: uint8
# Final check - Frame 89: shape (400, 600, 3), dtype: uint8
# Final check - Frame 90: shape (400, 600, 3), dtype: uint8
# Final check - Frame 91: shape (400, 600, 3), dtype: uint8
# Final check - Frame 92: shape (400, 600, 3), dtype: uint8
# Final check - Frame 93: shape (400, 600, 3), dtype: uint8
# Final check - Frame 94: shape (400, 600, 3), dtype: uint8
# Final check - Frame 95: shape (400, 600, 3), dtype: uint8
# Final check - Frame 96: shape (400, 600, 3), dtype: uint8
# Final check - Frame 97: shape (400, 600, 3), dtype: uint8
# Final check - Frame 98: shape (400, 600, 3), dtype: uint8
# Final check - Frame 99: shape (400, 600, 3), dtype: uint8
# Final check - Frame 100: shape (400, 600, 3), dtype: uint8
# Final check - Frame 101: shape (400, 600, 3), dtype: uint8
# Final check - Frame 102: shape (400, 600, 3), dtype: uint8
# Final check - Frame 103: shape (400, 600, 3), dtype: uint8
# Final check - Frame 104: shape (400, 600, 3), dtype: uint8
# Final check - Frame 105: shape (400, 600, 3), dtype: uint8
# Final check - Frame 106: shape (400, 600, 3), dtype: uint8
# Final check - Frame 107: shape (400, 600, 3), dtype: uint8
# Final check - Frame 108: shape (400, 600, 3), dtype: uint8
# Final check - Frame 109: shape (400, 600, 3), dtype: uint8
# Final check - Frame 110: shape (400, 600, 3), dtype: uint8
# Final check - Frame 111: shape (400, 600, 3), dtype: uint8
# Final check - Frame 112: shape (400, 600, 3), dtype: uint8
# Final check - Frame 113: shape (400, 600, 3), dtype: uint8
# Final check - Frame 114: shape (400, 600, 3), dtype: uint8
# Final check - Frame 115: shape (400, 600, 3), dtype: uint8
# Final check - Frame 116: shape (400, 600, 3), dtype: uint8
# Final check - Frame 117: shape (400, 600, 3), dtype: uint8
# Final check - Frame 118: shape (400, 600, 3), dtype: uint8
# Final check - Frame 119: shape (400, 600, 3), dtype: uint8
# Final check - Frame 120: shape (400, 600, 3), dtype: uint8
# Final check - Frame 121: shape (400, 600, 3), dtype: uint8
# Final check - Frame 122: shape (400, 600, 3), dtype: uint8
# Final check - Frame 123: shape (400, 600, 3), dtype: uint8
# Final check - Frame 124: shape (400, 600, 3), dtype: uint8
# Final check - Frame 125: shape (400, 600, 3), dtype: uint8
# Final check - Frame 126: shape (400, 600, 3), dtype: uint8
# Final check - Frame 127: shape (400, 600, 3), dtype: uint8
# Final check - Frame 128: shape (400, 600, 3), dtype: uint8
# Final check - Frame 129: shape (400, 600, 3), dtype: uint8
# Final check - Frame 130: shape (400, 600, 3), dtype: uint8
# Final check - Frame 131: shape (400, 600, 3), dtype: uint8
# Final check - Frame 132: shape (400, 600, 3), dtype: uint8
# Final check - Frame 133: shape (400, 600, 3), dtype: uint8
# Final check - Frame 134: shape (400, 600, 3), dtype: uint8
# Final check - Frame 135: shape (400, 600, 3), dtype: uint8
# Final check - Frame 136: shape (400, 600, 3), dtype: uint8
# Final check - Frame 137: shape (400, 600, 3), dtype: uint8
# Final check - Frame 138: shape (400, 600, 3), dtype: uint8
# Final check - Frame 139: shape (400, 600, 3), dtype: uint8
# Final check - Frame 140: shape (400, 600, 3), dtype: uint8
# Final check - Frame 141: shape (400, 600, 3), dtype: uint8
# Final check - Frame 142: shape (400, 600, 3), dtype: uint8
# Final check - Frame 143: shape (400, 600, 3), dtype: uint8
# Final check - Frame 144: shape (400, 600, 3), dtype: uint8
# Final check - Frame 145: shape (400, 600, 3), dtype: uint8
# Final check - Frame 146: shape (400, 600, 3), dtype: uint8
# Final check - Frame 147: shape (400, 600, 3), dtype: uint8
# Final check - Frame 148: shape (400, 600, 3), dtype: uint8
# Final check - Frame 149: shape (400, 600, 3), dtype: uint8
# Final check - Frame 150: shape (400, 600, 3), dtype: uint8
# Final check - Frame 151: shape (400, 600, 3), dtype: uint8
# Final check - Frame 152: shape (400, 600, 3), dtype: uint8
# Final check - Frame 153: shape (400, 600, 3), dtype: uint8
# Final check - Frame 154: shape (400, 600, 3), dtype: uint8
# Final check - Frame 155: shape (400, 600, 3), dtype: uint8
# Final check - Frame 156: shape (400, 600, 3), dtype: uint8
# Final check - Frame 157: shape (400, 600, 3), dtype: uint8
# Final check - Frame 158: shape (400, 600, 3), dtype: uint8
# Final check - Frame 159: shape (400, 600, 3), dtype: uint8
# Final check - Frame 160: shape (400, 600, 3), dtype: uint8
# Final check - Frame 161: shape (400, 600, 3), dtype: uint8
# Final check - Frame 162: shape (400, 600, 3), dtype: uint8
# Final check - Frame 163: shape (400, 600, 3), dtype: uint8
# Final check - Frame 164: shape (400, 600, 3), dtype: uint8
# Final check - Frame 165: shape (400, 600, 3), dtype: uint8
# Final check - Frame 166: shape (400, 600, 3), dtype: uint8
# Final check - Frame 167: shape (400, 600, 3), dtype: uint8
# Final check - Frame 168: shape (400, 600, 3), dtype: uint8
# Final check - Frame 169: shape (400, 600, 3), dtype: uint8
# Final check - Frame 170: shape (400, 600, 3), dtype: uint8
# Final check - Frame 171: shape (400, 600, 3), dtype: uint8
# Final check - Frame 172: shape (400, 600, 3), dtype: uint8
# Final check - Frame 173: shape (400, 600, 3), dtype: uint8
# Final check - Frame 174: shape (400, 600, 3), dtype: uint8
# Final check - Frame 175: shape (400, 600, 3), dtype: uint8
# Final check - Frame 176: shape (400, 600, 3), dtype: uint8
# Final check - Frame 177: shape (400, 600, 3), dtype: uint8
# Final check - Frame 178: shape (400, 600, 3), dtype: uint8
# Final check - Frame 179: shape (400, 600, 3), dtype: uint8
# Final check - Frame 180: shape (400, 600, 3), dtype: uint8
# Final check - Frame 181: shape (400, 600, 3), dtype: uint8
# Final check - Frame 182: shape (400, 600, 3), dtype: uint8
# Final check - Frame 183: shape (400, 600, 3), dtype: uint8
# Final check - Frame 184: shape (400, 600, 3), dtype: uint8
# Final check - Frame 185: shape (400, 600, 3), dtype: uint8
# Final check - Frame 186: shape (400, 600, 3), dtype: uint8
# Final check - Frame 187: shape (400, 600, 3), dtype: uint8
# Final check - Frame 188: shape (400, 600, 3), dtype: uint8
# Final check - Frame 189: shape (400, 600, 3), dtype: uint8
# Final check - Frame 190: shape (400, 600, 3), dtype: uint8
# Final check - Frame 191: shape (400, 600, 3), dtype: uint8
# Final check - Frame 192: shape (400, 600, 3), dtype: uint8
# Final check - Frame 193: shape (400, 600, 3), dtype: uint8
# Final check - Frame 194: shape (400, 600, 3), dtype: uint8
# Final check - Frame 195: shape (400, 600, 3), dtype: uint8
# Final check - Frame 196: shape (400, 600, 3), dtype: uint8
# Final check - Frame 197: shape (400, 600, 3), dtype: uint8
# Final check - Frame 198: shape (400, 600, 3), dtype: uint8
# Final check - Frame 199: shape (400, 600, 3), dtype: uint8
# Final check - Frame 200: shape (400, 600, 3), dtype: uint8
# Final check - Frame 201: shape (400, 600, 3), dtype: uint8
# Final check - Frame 202: shape (400, 600, 3), dtype: uint8
# Final check - Frame 203: shape (400, 600, 3), dtype: uint8
# Final check - Frame 204: shape (400, 600, 3), dtype: uint8
# Final check - Frame 205: shape (400, 600, 3), dtype: uint8
# Final check - Frame 206: shape (400, 600, 3), dtype: uint8
# Final check - Frame 207: shape (400, 600, 3), dtype: uint8
# Final check - Frame 208: shape (400, 600, 3), dtype: uint8
# Final check - Frame 209: shape (400, 600, 3), dtype: uint8
# Final check - Frame 210: shape (400, 600, 3), dtype: uint8
# Final check - Frame 211: shape (400, 600, 3), dtype: uint8
# Final check - Frame 212: shape (400, 600, 3), dtype: uint8
# Final check - Frame 213: shape (400, 600, 3), dtype: uint8
# Final check - Frame 214: shape (400, 600, 3), dtype: uint8
# Final check - Frame 215: shape (400, 600, 3), dtype: uint8
# Final check - Frame 216: shape (400, 600, 3), dtype: uint8
# Final check - Frame 217: shape (400, 600, 3), dtype: uint8
# Final check - Frame 218: shape (400, 600, 3), dtype: uint8
# Final check - Frame 219: shape (400, 600, 3), dtype: uint8
# Final check - Frame 220: shape (400, 600, 3), dtype: uint8
# Final check - Frame 221: shape (400, 600, 3), dtype: uint8
# Final check - Frame 222: shape (400, 600, 3), dtype: uint8
# Final check - Frame 223: shape (400, 600, 3), dtype: uint8
# Final check - Frame 224: shape (400, 600, 3), dtype: uint8
# Final check - Frame 225: shape (400, 600, 3), dtype: uint8
# Final check - Frame 226: shape (400, 600, 3), dtype: uint8
# Final check - Frame 227: shape (400, 600, 3), dtype: uint8
# Final check - Frame 228: shape (400, 600, 3), dtype: uint8
# Final check - Frame 229: shape (400, 600, 3), dtype: uint8
# Final check - Frame 230: shape (400, 600, 3), dtype: uint8
# Final check - Frame 231: shape (400, 600, 3), dtype: uint8
# Final check - Frame 232: shape (400, 600, 3), dtype: uint8
# Final check - Frame 233: shape (400, 600, 3), dtype: uint8
# Final check - Frame 234: shape (400, 600, 3), dtype: uint8
# Final check - Frame 235: shape (400, 600, 3), dtype: uint8
# Final check - Frame 236: shape (400, 600, 3), dtype: uint8
# Final check - Frame 237: shape (400, 600, 3), dtype: uint8
# Final check - Frame 238: shape (400, 600, 3), dtype: uint8
# Final check - Frame 239: shape (400, 600, 3), dtype: uint8
# Final check - Frame 240: shape (400, 600, 3), dtype: uint8
# Final check - Frame 241: shape (400, 600, 3), dtype: uint8
# Final check - Frame 242: shape (400, 600, 3), dtype: uint8
# Final check - Frame 243: shape (400, 600, 3), dtype: uint8
# Final check - Frame 244: shape (400, 600, 3), dtype: uint8
# Final check - Frame 245: shape (400, 600, 3), dtype: uint8
# Final check - Frame 246: shape (400, 600, 3), dtype: uint8
# Final check - Frame 247: shape (400, 600, 3), dtype: uint8
# Final check - Frame 248: shape (400, 600, 3), dtype: uint8
# Final check - Frame 249: shape (400, 600, 3), dtype: uint8
# Final check - Frame 250: shape (400, 600, 3), dtype: uint8
# Final check - Frame 251: shape (400, 600, 3), dtype: uint8
# Final check - Frame 252: shape (400, 600, 3), dtype: uint8
# Final check - Frame 253: shape (400, 600, 3), dtype: uint8
# Final check - Frame 254: shape (400, 600, 3), dtype: uint8
# Final check - Frame 255: shape (400, 600, 3), dtype: uint8
# Final check - Frame 256: shape (400, 600, 3), dtype: uint8
# Final check - Frame 257: shape (400, 600, 3), dtype: uint8
# Final check - Frame 258: shape (400, 600, 3), dtype: uint8
# Final check - Frame 259: shape (400, 600, 3), dtype: uint8
# Final check - Frame 260: shape (400, 600, 3), dtype: uint8
# Final check - Frame 261: shape (400, 600, 3), dtype: uint8
# Final check - Frame 262: shape (400, 600, 3), dtype: uint8
# Final check - Frame 263: shape (400, 600, 3), dtype: uint8
# Final check - Frame 264: shape (400, 600, 3), dtype: uint8
# Final check - Frame 265: shape (400, 600, 3), dtype: uint8
# Final check - Frame 266: shape (400, 600, 3), dtype: uint8
# Final check - Frame 267: shape (400, 600, 3), dtype: uint8
# Final check - Frame 268: shape (400, 600, 3), dtype: uint8
# Final check - Frame 269: shape (400, 600, 3), dtype: uint8
# Final check - Frame 270: shape (400, 600, 3), dtype: uint8
# Final check - Frame 271: shape (400, 600, 3), dtype: uint8
# Final check - Frame 272: shape (400, 600, 3), dtype: uint8
# Final check - Frame 273: shape (400, 600, 3), dtype: uint8
# Final check - Frame 274: shape (400, 600, 3), dtype: uint8
# Final check - Frame 275: shape (400, 600, 3), dtype: uint8
# Final check - Frame 276: shape (400, 600, 3), dtype: uint8
# Final check - Frame 277: shape (400, 600, 3), dtype: uint8
# Final check - Frame 278: shape (400, 600, 3), dtype: uint8
# Final check - Frame 279: shape (400, 600, 3), dtype: uint8
# Final check - Frame 280: shape (400, 600, 3), dtype: uint8
# Final check - Frame 281: shape (400, 600, 3), dtype: uint8
# Final check - Frame 282: shape (400, 600, 3), dtype: uint8
# Final check - Frame 283: shape (400, 600, 3), dtype: uint8
# Final check - Frame 284: shape (400, 600, 3), dtype: uint8
# Final check - Frame 285: shape (400, 600, 3), dtype: uint8
# Final check - Frame 286: shape (400, 600, 3), dtype: uint8
# Final check - Frame 287: shape (400, 600, 3), dtype: uint8
# Final check - Frame 288: shape (400, 600, 3), dtype: uint8
# Final check - Frame 289: shape (400, 600, 3), dtype: uint8
# Final check - Frame 290: shape (400, 600, 3), dtype: uint8
# Final check - Frame 291: shape (400, 600, 3), dtype: uint8
# Final check - Frame 292: shape (400, 600, 3), dtype: uint8
# Final check - Frame 293: shape (400, 600, 3), dtype: uint8
# Final check - Frame 294: shape (400, 600, 3), dtype: uint8
# Final check - Frame 295: shape (400, 600, 3), dtype: uint8
# Final check - Frame 296: shape (400, 600, 3), dtype: uint8
# Final check - Frame 297: shape (400, 600, 3), dtype: uint8
# Final check - Frame 298: shape (400, 600, 3), dtype: uint8
# Final check - Frame 299: shape (400, 600, 3), dtype: uint8
# Final check - Frame 300: shape (400, 600, 3), dtype: uint8
# Final check - Frame 301: shape (400, 600, 3), dtype: uint8
# Final check - Frame 302: shape (400, 600, 3), dtype: uint8
# Final check - Frame 303: shape (400, 600, 3), dtype: uint8
# Final check - Frame 304: shape (400, 600, 3), dtype: uint8
# Final check - Frame 305: shape (400, 600, 3), dtype: uint8
# Final check - Frame 306: shape (400, 600, 3), dtype: uint8
# Final check - Frame 307: shape (400, 600, 3), dtype: uint8
# Final check - Frame 308: shape (400, 600, 3), dtype: uint8
# Final check - Frame 309: shape (400, 600, 3), dtype: uint8
# Final check - Frame 310: shape (400, 600, 3), dtype: uint8
# Final check - Frame 311: shape (400, 600, 3), dtype: uint8
# Final check - Frame 312: shape (400, 600, 3), dtype: uint8
# Final check - Frame 313: shape (400, 600, 3), dtype: uint8
# Final check - Frame 314: shape (400, 600, 3), dtype: uint8
# Final check - Frame 315: shape (400, 600, 3), dtype: uint8
# Final check - Frame 316: shape (400, 600, 3), dtype: uint8
# Final check - Frame 317: shape (400, 600, 3), dtype: uint8
# Final check - Frame 318: shape (400, 600, 3), dtype: uint8
# Final check - Frame 319: shape (400, 600, 3), dtype: uint8
# Final check - Frame 320: shape (400, 600, 3), dtype: uint8
# Final check - Frame 321: shape (400, 600, 3), dtype: uint8
# Final check - Frame 322: shape (400, 600, 3), dtype: uint8
# Final check - Frame 323: shape (400, 600, 3), dtype: uint8
# Final check - Frame 324: shape (400, 600, 3), dtype: uint8
# Final check - Frame 325: shape (400, 600, 3), dtype: uint8
# Final check - Frame 326: shape (400, 600, 3), dtype: uint8
# Final check - Frame 327: shape (400, 600, 3), dtype: uint8
# Final check - Frame 328: shape (400, 600, 3), dtype: uint8
# Final check - Frame 329: shape (400, 600, 3), dtype: uint8
# Final check - Frame 330: shape (400, 600, 3), dtype: uint8
# Final check - Frame 331: shape (400, 600, 3), dtype: uint8
# Final check - Frame 332: shape (400, 600, 3), dtype: uint8
# Final check - Frame 333: shape (400, 600, 3), dtype: uint8
# Final check - Frame 334: shape (400, 600, 3), dtype: uint8
# Final check - Frame 335: shape (400, 600, 3), dtype: uint8
# Final check - Frame 336: shape (400, 600, 3), dtype: uint8
# Final check - Frame 337: shape (400, 600, 3), dtype: uint8
# Final check - Frame 338: shape (400, 600, 3), dtype: uint8
# Final check - Frame 339: shape (400, 600, 3), dtype: uint8
# Final check - Frame 340: shape (400, 600, 3), dtype: uint8
# Final check - Frame 341: shape (400, 600, 3), dtype: uint8
# Final check - Frame 342: shape (400, 600, 3), dtype: uint8
# Final check - Frame 343: shape (400, 600, 3), dtype: uint8
# Final check - Frame 344: shape (400, 600, 3), dtype: uint8
# Final check - Frame 345: shape (400, 600, 3), dtype: uint8
# Final check - Frame 346: shape (400, 600, 3), dtype: uint8
# Final check - Frame 347: shape (400, 600, 3), dtype: uint8
# Final check - Frame 348: shape (400, 600, 3), dtype: uint8
# Final check - Frame 349: shape (400, 600, 3), dtype: uint8
# Final check - Frame 350: shape (400, 600, 3), dtype: uint8
# Final check - Frame 351: shape (400, 600, 3), dtype: uint8
# Final check - Frame 352: shape (400, 600, 3), dtype: uint8
# Final check - Frame 353: shape (400, 600, 3), dtype: uint8
# Final check - Frame 354: shape (400, 600, 3), dtype: uint8
# Final check - Frame 355: shape (400, 600, 3), dtype: uint8
# Final check - Frame 356: shape (400, 600, 3), dtype: uint8
# Final check - Frame 357: shape (400, 600, 3), dtype: uint8
# Final check - Frame 358: shape (400, 600, 3), dtype: uint8
# Final check - Frame 359: shape (400, 600, 3), dtype: uint8
# Final check - Frame 360: shape (400, 600, 3), dtype: uint8
# Final check - Frame 361: shape (400, 600, 3), dtype: uint8
# Final check - Frame 362: shape (400, 600, 3), dtype: uint8
# Final check - Frame 363: shape (400, 600, 3), dtype: uint8
# Final check - Frame 364: shape (400, 600, 3), dtype: uint8
# Final check - Frame 365: shape (400, 600, 3), dtype: uint8
# Final check - Frame 366: shape (400, 600, 3), dtype: uint8
# Final check - Frame 367: shape (400, 600, 3), dtype: uint8
# Final check - Frame 368: shape (400, 600, 3), dtype: uint8
# Final check - Frame 369: shape (400, 600, 3), dtype: uint8
# Final check - Frame 370: shape (400, 600, 3), dtype: uint8
# Final check - Frame 371: shape (400, 600, 3), dtype: uint8
# Final check - Frame 372: shape (400, 600, 3), dtype: uint8
# Final check - Frame 373: shape (400, 600, 3), dtype: uint8
# Final check - Frame 374: shape (400, 600, 3), dtype: uint8
# Final check - Frame 375: shape (400, 600, 3), dtype: uint8
# Final check - Frame 376: shape (400, 600, 3), dtype: uint8
# Final check - Frame 377: shape (400, 600, 3), dtype: uint8
# Final check - Frame 378: shape (400, 600, 3), dtype: uint8
# Final check - Frame 379: shape (400, 600, 3), dtype: uint8
# Final check - Frame 380: shape (400, 600, 3), dtype: uint8
# Final check - Frame 381: shape (400, 600, 3), dtype: uint8
# Final check - Frame 382: shape (400, 600, 3), dtype: uint8
# Final check - Frame 383: shape (400, 600, 3), dtype: uint8
# Final check - Frame 384: shape (400, 600, 3), dtype: uint8
# Final check - Frame 385: shape (400, 600, 3), dtype: uint8
# Final check - Frame 386: shape (400, 600, 3), dtype: uint8
# Final check - Frame 387: shape (400, 600, 3), dtype: uint8
# Final check - Frame 388: shape (400, 600, 3), dtype: uint8
# Final check - Frame 389: shape (400, 600, 3), dtype: uint8
# Final check - Frame 390: shape (400, 600, 3), dtype: uint8
# Final check - Frame 391: shape (400, 600, 3), dtype: uint8
# Final check - Frame 392: shape (400, 600, 3), dtype: uint8
# Final check - Frame 393: shape (400, 600, 3), dtype: uint8
# Final check - Frame 394: shape (400, 600, 3), dtype: uint8
# Final check - Frame 395: shape (400, 600, 3), dtype: uint8
# Final check - Frame 396: shape (400, 600, 3), dtype: uint8
# Final check - Frame 397: shape (400, 600, 3), dtype: uint8
# Final check - Frame 398: shape (400, 600, 3), dtype: uint8
# Final check - Frame 399: shape (400, 600, 3), dtype: uint8
# Final check - Frame 400: shape (400, 600, 3), dtype: uint8
# Final check - Frame 401: shape (400, 600, 3), dtype: uint8
# Final check - Frame 402: shape (400, 600, 3), dtype: uint8
# Final check - Frame 403: shape (400, 600, 3), dtype: uint8
# Final check - Frame 404: shape (400, 600, 3), dtype: uint8
# Final check - Frame 405: shape (400, 600, 3), dtype: uint8
# Final check - Frame 406: shape (400, 600, 3), dtype: uint8
# Final check - Frame 407: shape (400, 600, 3), dtype: uint8
# Final check - Frame 408: shape (400, 600, 3), dtype: uint8
# Final check - Frame 409: shape (400, 600, 3), dtype: uint8
# Final check - Frame 410: shape (400, 600, 3), dtype: uint8
# Final check - Frame 411: shape (400, 600, 3), dtype: uint8
# Final check - Frame 412: shape (400, 600, 3), dtype: uint8
# Final check - Frame 413: shape (400, 600, 3), dtype: uint8
# Final check - Frame 414: shape (400, 600, 3), dtype: uint8
# Final check - Frame 415: shape (400, 600, 3), dtype: uint8
# Final check - Frame 416: shape (400, 600, 3), dtype: uint8
# Final check - Frame 417: shape (400, 600, 3), dtype: uint8
# Final check - Frame 418: shape (400, 600, 3), dtype: uint8
# Final check - Frame 419: shape (400, 600, 3), dtype: uint8
# Final check - Frame 420: shape (400, 600, 3), dtype: uint8
# Final check - Frame 421: shape (400, 600, 3), dtype: uint8
# Final check - Frame 422: shape (400, 600, 3), dtype: uint8
# Final check - Frame 423: shape (400, 600, 3), dtype: uint8
# Final check - Frame 424: shape (400, 600, 3), dtype: uint8
# Final check - Frame 425: shape (400, 600, 3), dtype: uint8
# Final check - Frame 426: shape (400, 600, 3), dtype: uint8
# Final check - Frame 427: shape (400, 600, 3), dtype: uint8
# Final check - Frame 428: shape (400, 600, 3), dtype: uint8
# Final check - Frame 429: shape (400, 600, 3), dtype: uint8
# Final check - Frame 430: shape (400, 600, 3), dtype: uint8
# Final check - Frame 431: shape (400, 600, 3), dtype: uint8
# Final check - Frame 432: shape (400, 600, 3), dtype: uint8
# Final check - Frame 433: shape (400, 600, 3), dtype: uint8
# Final check - Frame 434: shape (400, 600, 3), dtype: uint8
# Final check - Frame 435: shape (400, 600, 3), dtype: uint8
# Final check - Frame 436: shape (400, 600, 3), dtype: uint8
# Final check - Frame 437: shape (400, 600, 3), dtype: uint8
# Final check - Frame 438: shape (400, 600, 3), dtype: uint8
# Final check - Frame 439: shape (400, 600, 3), dtype: uint8
# Final check - Frame 440: shape (400, 600, 3), dtype: uint8
# Final check - Frame 441: shape (400, 600, 3), dtype: uint8
# Final check - Frame 442: shape (400, 600, 3), dtype: uint8
# Final check - Frame 443: shape (400, 600, 3), dtype: uint8
# Final check - Frame 444: shape (400, 600, 3), dtype: uint8
# Final check - Frame 445: shape (400, 600, 3), dtype: uint8
# Final check - Frame 446: shape (400, 600, 3), dtype: uint8
# Final check - Frame 447: shape (400, 600, 3), dtype: uint8
# Final check - Frame 448: shape (400, 600, 3), dtype: uint8
# Final check - Frame 449: shape (400, 600, 3), dtype: uint8
# Final check - Frame 450: shape (400, 600, 3), dtype: uint8
# Final check - Frame 451: shape (400, 600, 3), dtype: uint8
# Final check - Frame 452: shape (400, 600, 3), dtype: uint8
# Final check - Frame 453: shape (400, 600, 3), dtype: uint8
# Final check - Frame 454: shape (400, 600, 3), dtype: uint8
# Final check - Frame 455: shape (400, 600, 3), dtype: uint8
# Final check - Frame 456: shape (400, 600, 3), dtype: uint8
# Final check - Frame 457: shape (400, 600, 3), dtype: uint8
# Final check - Frame 458: shape (400, 600, 3), dtype: uint8
# Final check - Frame 459: shape (400, 600, 3), dtype: uint8
# Final check - Frame 460: shape (400, 600, 3), dtype: uint8
# Final check - Frame 461: shape (400, 600, 3), dtype: uint8
# Final check - Frame 462: shape (400, 600, 3), dtype: uint8
# Final check - Frame 463: shape (400, 600, 3), dtype: uint8
# Final check - Frame 464: shape (400, 600, 3), dtype: uint8
# Final check - Frame 465: shape (400, 600, 3), dtype: uint8
# Final check - Frame 466: shape (400, 600, 3), dtype: uint8
# Final check - Frame 467: shape (400, 600, 3), dtype: uint8
# Final check - Frame 468: shape (400, 600, 3), dtype: uint8
# Final check - Frame 469: shape (400, 600, 3), dtype: uint8
# Final check - Frame 470: shape (400, 600, 3), dtype: uint8
# Final check - Frame 471: shape (400, 600, 3), dtype: uint8
# Final check - Frame 472: shape (400, 600, 3), dtype: uint8
# Final check - Frame 473: shape (400, 600, 3), dtype: uint8
# Final check - Frame 474: shape (400, 600, 3), dtype: uint8
# Final check - Frame 475: shape (400, 600, 3), dtype: uint8
# Final check - Frame 476: shape (400, 600, 3), dtype: uint8
# Final check - Frame 477: shape (400, 600, 3), dtype: uint8
# Final check - Frame 478: shape (400, 600, 3), dtype: uint8
# Final check - Frame 479: shape (400, 600, 3), dtype: uint8
# Final check - Frame 480: shape (400, 600, 3), dtype: uint8
# Final check - Frame 481: shape (400, 600, 3), dtype: uint8
# Final check - Frame 482: shape (400, 600, 3), dtype: uint8
# Final check - Frame 483: shape (400, 600, 3), dtype: uint8
# Final check - Frame 484: shape (400, 600, 3), dtype: uint8
# Final check - Frame 485: shape (400, 600, 3), dtype: uint8
# Final check - Frame 486: shape (400, 600, 3), dtype: uint8
# Final check - Frame 487: shape (400, 600, 3), dtype: uint8
# Final check - Frame 488: shape (400, 600, 3), dtype: uint8
# Final check - Frame 489: shape (400, 600, 3), dtype: uint8
# Final check - Frame 490: shape (400, 600, 3), dtype: uint8
# Final check - Frame 491: shape (400, 600, 3), dtype: uint8
# Final check - Frame 492: shape (400, 600, 3), dtype: uint8
# Final check - Frame 493: shape (400, 600, 3), dtype: uint8
# Final check - Frame 494: shape (400, 600, 3), dtype: uint8
# Final check - Frame 495: shape (400, 600, 3), dtype: uint8
# Final check - Frame 496: shape (400, 600, 3), dtype: uint8
# Final check - Frame 497: shape (400, 600, 3), dtype: uint8
# Final check - Frame 498: shape (400, 600, 3), dtype: uint8
#     <video width=400 controls>
#           <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
show_video('./test.mp4')
# Out:
#     <video width=400 controls>
#           <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
